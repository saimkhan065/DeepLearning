# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator
#from tensorflow.keras.models import Model
#from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
base_dir='/Users/root1/Documents/Coursera DeepLearning/Course2/RPS'

# %%
train_dir=os.path.join(base_dir,'train')
test_dir=os.path.join(base_dir,'test')

# %%
train_datagen=ImageDataGenerator(rescale=1/255,
                                rotation_range=0.5,
                                height_shift_range=0.2,
                                width_shift_range=0.2,
                                shear_range=0.5,
                                horizontal_flip=True)
validation_datagen=ImageDataGenerator(rescale=1/255)

# %%
train_generator=train_datagen.flow_from_directory(train_dir,
                                                class_mode='categorical',
                                                  batch_size=25,
                                                target_size=(150,150))
test_generator=validation_datagen.flow_from_directory(test_dir,
                                                     class_mode='categorical',
                                                      batch_size=25,
                                                     target_size=(150,150))
# Out:
# Found 2520 images belonging to 3 classes.
# Found 372 images belonging to 3 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(3,activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_8 (Conv2D)            (None, 148, 148, 64)      1792
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 72, 72, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 15, 256)       295168
# ...

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_generator,validation_data=test_generator,steps_per_epoch=20,
                   epochs=15,validation_steps=3,verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 20 steps, validate for 3 steps
# Epoch 1/15
# 20/20 [==============================] - 14s 694ms/step - loss: 0.3857 - accuracy: 0.8444 - val_loss: 0.0814 - val_accuracy: 0.9867
# Epoch 2/15
# 20/20 [==============================] - 15s 773ms/step - loss: 0.3967 - accuracy: 0.8620 - val_loss: 0.0686 - val_accuracy: 1.0000
# Epoch 3/15
# 20/20 [==============================] - 14s 699ms/step - loss: 0.1980 - accuracy: 0.9240 - val_loss: 1.1204 - val_accuracy: 0.7067
# Epoch 4/15
# 20/20 [==============================] - 14s 710ms/step - loss: 0.2597 - accuracy: 0.9080 - val_loss: 0.0437 - val_accuracy: 1.0000
# Epoch 5/15
# 20/20 [==============================] - 13s 655ms/step - loss: 0.2669 - accuracy: 0.9180 - val_loss: 0.2785 - val_accuracy: 0.9200
# Epoch 6/15
# ...

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()


plt.show()

# %%
import numpy as np
p = '/Users/root1/Documents/Coursera DeepLearning/Course2/RPS/predict'
for fn in os.listdir(p):
    path = os.path.join(p,fn)
    img=image.load_img(path,target_size=(150,150))
    x=image.img_to_array(img)
    x=np.expand_dims(x,axis=0)
    
    images=np.vstack([x])
    classes=model.predict(images,batch_size=10)
    plt.imshow(img)
    plt.show()
    print(fn)
    print(classes)
# Out:
# scissors-hires1.png
# [[0. 0. 1.]]
# scissors-hires2.png
# [[0. 0. 1.]]
# rock3.png
# [[0. 1. 0.]]
# paper4.png
# [[1. 0. 0.]]
# paper5.png
# [[1. 0. 0.]]
# rock2.png
# [[0. 1. 0.]]
# paper7.png
# [[1. 0. 0.]]
# paper6.png
# [[1. 0. 0.]]
# rock1.png
# [[0. 1. 0.]]
# rock5.png
# [[0. 1. 0.]]
# scissors9.png
# [[0. 0. 1.]]
# paper2.png
# [[1. 0. 0.]]
# rock-hires2.png
# [[0. 1. 0.]]
# paper3.png
# [[0. 0. 1.]]
# paper-hires1.png
# [[1. 0. 0.]]
# scissors8.png
# [[0. 0. 1.]]
# rock4.png
# [[0. 1. 0.]]
# rock6.png
# [[0. 1. 0.]]
# paper1.png
# [[1. 0. 0.]]
# rock-hires1.png
# [[0. 1. 0.]]
# paper-hires2.png
# [[1. 0. 0.]]
# rock7.png
# [[0. 1. 0.]]
# scissors6.png
# [[0. 0. 1.]]
# scissors7.png
# [[0. 0. 1.]]
# rock9.png
# [[0. 1. 0.]]
# scissors5.png
# [[0. 0. 1.]]
# scissors4.png
# [[0. 0. 1.]]
# rock8.png
# [[0. 1. 0.]]
# scissors1.png
# [[0. 0. 1.]]
# scissors3.png
# [[0. 0. 1.]]
# paper8.png
# [[1. 0. 0.]]
# paper9.png
# [[1.0000000e+00 0.0000000e+00 2.6823114e-23]]
# scissors2.png
# ...

# %%
classes
# Out:
# array([[0., 0., 1.]], dtype=float32)
